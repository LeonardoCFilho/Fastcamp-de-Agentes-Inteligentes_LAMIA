# %% [markdown]
# [Fundamentos dos sistemas de vários agentes com ADK](https://www.youtube.com/watch?v=P4VFL9nIaIA&t=5462s)

# %%
# Importando do .env

from dotenv import load_dotenv
import os
from pathlib import Path

load_dotenv(dotenv_path=Path("../.env"))

GROQ_API_KEY = os.getenv("GROQ_API_KEY")
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
# !pip install google-adk -q
# !pip install litellm -q

# %% [markdown]
# # Exemplo 7: Multiagente

# %%
""" Ideia do novo sistema multi agente:
Garantir uma alimentação saudável de modo fácil 

Um agente, com acesso a internet, foca em achar receitas
Outro agente foca na saúde (alimentação e exercícios do usuário)

Possibilitando o usuário apenas pedir receitas aleatórias, ou pedir a ajuda para uma receita mais saudável
"""

from dotenv import load_dotenv
from pathlib import Path
load_dotenv(dotenv_path=Path("../.env"))

import asyncio
from google.adk.runners import Runner
from google.adk.sessions import InMemorySessionService
from google.genai.types import Content, Part

from Multiagente.pratica.agent import root_agent

APP_NAME = "multi_agent_app"
USER_ID = "user_1"
SESSION_ID = "session_1"

session_service = InMemorySessionService()

async def run(message: str):
    await session_service.create_session(
        app_name=APP_NAME,
        user_id=USER_ID,
        session_id=SESSION_ID
    )

    runner = Runner(
        agent=root_agent,
        app_name=APP_NAME,
        session_service=session_service,
    )

    content = Content(role="user", parts=[Part(text=message)])
    events = runner.run(
        user_id=USER_ID,
        session_id=SESSION_ID,
        new_message=content,
    )
    for event in events:
        if event.is_final_response():
            print(event.response.text)

await run("Me sugira uma receita com frango e batata")
# Out:
# Exception in thread Thread-13 (_asyncio_thread_main):
# Traceback (most recent call last):
#   File "/home/leonaardo/Downloads/Fastcamp-de-Agentes-Inteligentes_LAMIA/.venv/lib/python3.12/site-packages/google/adk/models/google_llm.py", line 245, in generate_content_async
#     response = await self.api_client.aio.models.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/leonaardo/Downloads/Fastcamp-de-Agentes-Inteligentes_LAMIA/.venv/lib/python3.12/site-packages/google/genai/models.py", line 7718, in generate_content
#     return await self._generate_content(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/leonaardo/Downloads/Fastcamp-de-Agentes-Inteligentes_LAMIA/.venv/lib/python3.12/site-packages/google/genai/models.py", line 6485, in _generate_content
#     response = await self._api_client.async_request(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %% [markdown]
# # Exemplo 8: Multiagente com estados

# %% [markdown]
# ## Resultado da Aula

# %% [markdown]
# ## Resultado prático

# %% [markdown]
# # Exemplo 9: Callbacks

# %% [markdown]
# ## Resultado da Aula

# %% [markdown]
# ## Resultado prático

# %% [markdown]
# ## Exemplo 10: Agente sequencial

# %% [markdown]
# ## Resultado da Aula

# %% [markdown]
# ## Resultado prático

# %% [markdown]
# # Exemplo 11: Agente paralelo

# %% [markdown]
# ## Resultado da Aula

# %% [markdown]
# ## Resultado prático

# %% [markdown]
# # Exemplo 12: Agente em loop

# %% [markdown]
# ## Resultado da Aula

# %% [markdown]
# ## Resultado prático
