# %% [markdown]
# # Configurando kernel

# %%
# %pip install -q google-adk litellm fastapi uvicorn httpx pydantic openai streamlit
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importando do .env

from dotenv import load_dotenv
import os
from pathlib import Path

load_dotenv(dotenv_path=Path("../.env"))

GROQ_API_KEY = os.getenv("GROQ_API_KEY")
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
import streamlit as st
import requests, asyncio

# %% [markdown]
# ## Implementando o frontend

# %%
# Original
# !uvicorn agents.host_agent.__main__:app --port 8000 & uvicorn agents.flight_agent.__main__:app --port 8001 & uvicorn agents.stay_agent.__main__:app --port 8002 & uvicorn agents.activities_agent.__main__:app --port 8003 & streamlit run travel_ui.py

# Editado para melhorar o funcionamento via ipynb
# Ainda não funcionou, mas a saida foi copiada e colada abaixo
try:
    # !uvicorn agents.host_agent.__main__:app --port 8000 & uvicorn agents.flight_agent.__main__:app --port 8001 & uvicorn agents.stay_agent.__main__:app --port 8002 & uvicorn agents.activities_agent.__main__:app --port 8003 & streamlit run travel_ui.py
except asyncio.CancelledError:
    print("Programa finalizado!")
# Out:
# INFO:     Started server process [30343]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://192.168.1.4:8501
#
# INFO:     Started server process [30346]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8003 (Press CTRL+C to quit)
# INFO:     Started server process [30345]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8002 (Press CTRL+C to quit)
# INFO:     Started server process [30344]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8001 (Press CTRL+C to quit)
# ...

# %% [markdown]
# # Saida literal (copy paste)
#
# ## ✈️ Flights
# ```json
# {
#   "flights": [
#     {
#       "company": "Japan Airlines",
#       "price_estimate": 8000,
#       "departure_time": "2026-04-01 10:00",
#       "flight_details": "JL123, Non-stop, Boeing 777, 9 hours 30 minutes"
#     },
#     {
#       "company": "ANA",
#       "price_estimate": 9000,
#       "departure_time": "2026-04-01 12:00",
#       "flight_details": "NH456, 1 stop, Airbus A350, 11 hours 30 minutes"
#     },
#     {
#       "company": "Delta Air Lines",
#       "price_estimate": 9500,
#       "departure_time": "2026-04-01 14:00",
#       "flight_details": "DL789, Non-stop, Airbus A330, 10 hours 45 minutes"
#     }
#   ]
# }
# ```
#
# ## 🏨 Stays
# ```json
# {
#   "stays": [
#     {
#       "name": "Remm Akihabara Hotel",
#       "type": "Hotel",
#       "price Estimate Per Night": 8000,
#       "location/neighborhood": "Akihabara, Chiyoda-ku",
#       "main highlights": "Modern rooms, convenient location, easy access to Tokyo's electronics and anime hub"
#     },
#     {
#       "name": "Nui.Tokyo Central Hostel",
#       "type": "Hostel",
#       "price Estimate Per Night": 2500,
#       "location/neighborhood": "Shinjuku-ku",
#       "main highlights": "Social atmosphere, communal kitchen, close to Shinjuku Gyoen National Garden"
#     },
#     {
#       "name": "Tokyo Shinjuku AirBnB",
#       "type": "AirBnB",
#       "price Estimate Per Night": 5000,
#       "location/neighborhood": "Shinjuku-ku, Kabukicho",
#       "main highlights": "Private apartment, fully equipped kitchen, walking distance to Shinjuku Station"
#     }
#   ]
# }
# ```
#
# ## 🗺️ Activities
# ```json
# {
#   "activities": [
#     {
#       "name": "Tokyo Skytree Visit",
#       "description": "Enjoy panoramic views of Tokyo from the tallest tower in the world",
#       "price_estimate": 2000,
#       "duration": 2
#     },
#     {
#       "name": "Shibuya Crossing Experience",
#       "description": "Walk around the famous Shibuya area, take a walk around the popular scramble crossing and grab a coffee at one of the trendy cafes",
#       "price_estimate": 1000,
#       "duration": 3
#     },
#     {
#       "name": "Meiji Shrine Tour",
#       "description": "Explore the serene Shinto shrine dedicated to the deified spirits of Emperor Meiji and his wife, Empress Shoken",
#       "price_estimate": 500,
#       "duration": 2
#     }
#   ]
# }
# ```
