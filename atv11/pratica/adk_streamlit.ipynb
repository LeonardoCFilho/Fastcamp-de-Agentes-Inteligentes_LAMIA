# %% [markdown]
# # Configurando kernel

# %%
# %pip install -q google-adk litellm fastapi uvicorn httpx pydantic openai streamlit
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importando do .env

from dotenv import load_dotenv
import os
from pathlib import Path

load_dotenv(dotenv_path=Path("../.env"))

GROQ_API_KEY = os.getenv("GROQ_API_KEY")
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
import streamlit as st
import requests, asyncio

# %% [markdown]
# ## Implementando o frontend

# %%
# Original
# !uvicorn agents.host_agent.__main__:app --port 8000 & uvicorn agents.budget_agent.__main__:app --port 8001 & uvicorn agents.savings_agent.__main__:app --port 8002 & uvicorn agents.debt_agent.__main__:app --port 8003 & streamlit run finance_ui.py

# Editado para melhorar o funcionamento via ipynb
# Ainda não funcionou, mas a saida foi copiada e colada abaixo
try:
    # !uvicorn agents.host_agent.__main__:app --port 8000 & uvicorn agents.budget_agent.__main__:app --port 8001 & uvicorn agents.savings_agent.__main__:app --port 8002 & uvicorn agents.debt_agent.__main__:app --port 8003 & streamlit run finance_ui.py
except asyncio.CancelledError:
    print("Programa finalizado!")
# Out:
# INFO:     Started server process [35278]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://192.168.1.4:8501
#
# INFO:     Started server process [35279]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8001 (Press CTRL+C to quit)
# INFO:     Started server process [35281]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8003 (Press CTRL+C to quit)
# INFO:     Started server process [35280]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8002 (Press CTRL+C to quit)
# ...

# %% [markdown]
# # Saida literal (copy paste)
#
# 📊 Budget
# ```
# [
# 0:{
# "category":"Housing"
# "suggested_amount":800
# "tip":"Consider downsizing or finding a roommate to reduce housing costs."
# }
# 1:{
# "category":"Food"
# "suggested_amount":300
# "tip":"Plan your meals, use coupons, and buy groceries in bulk to save money."
# }
# 2:{
# "category":"Transport"
# "suggested_amount":100
# "tip":"Explore public transportation options, walk, or bike when possible to reduce fuel and maintenance costs."
# }
# 3:{
# "category":"Leisure"
# "suggested_amount":200
# "tip":"Look for free or low-cost entertainment options, such as parks, museums, or game nights with friends."
# }
# 4:{
# "category":"Savings"
# "suggested_amount":500
# "tip":"Set up automatic transfers to your savings account to build an emergency fund and work towards long-term goals."
# }
# 5:{
# "category":"Miscellaneous"
# "suggested_amount":100
# "tip":"Review your budget regularly and adjust as needed to ensure you're covering all necessary expenses."
# }
# ]
# ```
#
# ## 🏦 Savings
# ```
# [
# 0:{
# "goal":"Emergency Fund"
# "monthly_amount":200
# "rationale":"Having 3-6 months' worth of expenses in an easily accessible savings account for unexpected events"
# }
# 1:{
# "goal":"Retirement Savings"
# "monthly_amount":300
# "rationale":"Utilizing tax-advantaged accounts such as a Roth IRA or 401(k) for long-term growth"
# }
# 2:{
# "goal":"Wealth Building"
# "monthly_amount":500
# "rationale":"Investing in a beginner-friendly index fund or ETF for potential long-term returns"
# }
# ]
# ```
#
# 💳 Debt Strategy
# ```
# [
# 0:{
# "strategy":"Aggressive"
# "monthly_payment":1000
# "estimated_payoff_months":50
# }
# 1:{
# "strategy":"Moderate"
# "monthly_payment":750
# "estimated_payoff_months":67
# }
# 2:{
# "strategy":"Conservative"
# "monthly_payment":500
# "estimated_payoff_months":100
# }
# ]
# ```

# %% [markdown]
# Honestamente a saída foi menos padronizada que eu esperava, ter que padronizar a saida apos o modelo responder (sem da erro) acabou atrapalhando a resposta final, é fácil de formatar, mas essa complexidade extra nesse caso não compensa.
# Ainda assim, isso poderia ser útil em casos de conversa direta entre sub-agentes, essa padronização de saida (.json) facilita bastante a contextualização dos outros
#
# Além disso, considerando a ideia de ajuda financeira eles foram 'bem', a matematica esta correta, mas a ideia que o usuário gastaria perfeitamente 2k e usaria todo o resto (1k) é mais do que agressivo, ainda assim, para um caso simples como esse e com o groq os resultados foram bem satisfatorios.
